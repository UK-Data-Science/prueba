# %%
import pandas as pd

linkGit="https://github.com/UK-Data-Science/tarea2Sebastian/raw/main/dataUN%20-%20HDR21-22_Statistical_Annex_HDI_Table.csv"

data=pd.read_csv(linkGit)
data
# Out:
#          Back Table 1. Human Development Index and its components  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4    HDI rank                                            Country
# ..        ...                                                ...
# 271       NaN                          Column 2: UNDESA (2022a).
# 272       NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 273       NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 274       NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 275       NaN  Column 6: Calculated based on data in columns ...
#
#                         Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                              NaN         NaN                       NaN
# ...

# %%
#CLEANING
#Columns
#Delete the columns that are not going to be used
byeColumns=['Back','Unnamed: 3','Unnamed: 5','Unnamed: 7','Unnamed: 9','Unnamed: 11','Unnamed: 13']
data.drop(columns=byeColumns,inplace=True)

# %%
#Check the first 6 rows for data
data.head(6)
# Out:
#   Table 1. Human Development Index and its components  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            Country
# 5                                                NaN
#
#                       Unnamed: 2                Unnamed: 4  \
# 0                            NaN                       NaN
# 1                            NaN                      SDG3
# 2                            NaN                       NaN
# 3  Human Development Index (HDI)  Life expectancy at birth
# 4                          Value                   (years)
# 5                           2021                      2021
#
#                     Unnamed: 6               Unnamed: 8  \
# 0                          NaN                      NaN
# 1                       SDG4.3                   SDG4.4
# ...

# %%
#Replace the columns names with the third row values and their year 
data.columns=data.iloc[3,:]+" "+data.iloc[5,:]
data.columns
# Out:
# Index([                                          nan,
#                 'Human Development Index (HDI) 2021',
#                      'Life expectancy at birth 2021',
#                   'Expected years of schooling 2021',
#                       'Mean years of schooling 2021',
#        'Gross national income (GNI) per capita 2021',
#            'GNI per capita rank minus HDI rank 2021',
#                                      'HDI rank 2020'],
#       dtype='object')

# %%
#Rename the first column name
newColumns={data.columns[0]:data.iloc[4,0]}
data.rename(columns=newColumns,inplace=True)
data.columns
# Out:
# Index(['Country', 'Human Development Index (HDI) 2021',
#        'Life expectancy at birth 2021', 'Expected years of schooling 2021',
#        'Mean years of schooling 2021',
#        'Gross national income (GNI) per capita 2021',
#        'GNI per capita rank minus HDI rank 2021', 'HDI rank 2020'],
#       dtype='object')

# %%
#Replace spaces and weird symbols in the columns names
newColumns=data.columns.str.strip().\
                            str.replace(pat=r'\s',
                                         repl='_',
                                         regex=True).\
                              str.replace(pat=r'\W',
                                          repl='',
                                          regex=True)

newColumns={data.columns[0]:newColumns[0],data.columns[1]:newColumns[1],data.columns[2]:newColumns[2],data.columns[3]:newColumns[3],data.columns[4]:newColumns[4],data.columns[5]:newColumns[5],data.columns[6]:newColumns[6],data.columns[7]:newColumns[7]}
data.rename(columns=newColumns,inplace=True)
data.columns
# Out:
# Index(['Country', 'Human_Development_Index_HDI_2021',
#        'Life_expectancy_at_birth_2021', 'Expected_years_of_schooling_2021',
#        'Mean_years_of_schooling_2021',
#        'Gross_national_income_GNI_per_capita_2021',
#        'GNI_per_capita_rank_minus_HDI_rank_2021', 'HDI_rank_2020'],
#       dtype='object')

# %%
#Columns names too large, rename with a shorter name
newColumns={data.columns[1]:'HDI_2021',data.columns[2]:'Life_expec_2021',data.columns[3]:'Expec_years_school_2021',data.columns[4]:'Mean_years_school_2021',data.columns[5]:'GNI_2021',data.columns[6]:'GNI_minus_HDI_rank_2021'}
data.rename(columns=newColumns,inplace=True)
data.columns
# Out:
# Index(['Country', 'HDI_2021', 'Life_expec_2021', 'Expec_years_school_2021',
#        'Mean_years_school_2021', 'GNI_2021', 'GNI_minus_HDI_rank_2021',
#        'HDI_rank_2020'],
#       dtype='object')

# %%
#Categories
#Search for any row used to classify the data
cat=data[pd.isnull(data.HDI_2021)]
cat.Country=cat.Country.str.replace(pat=r'\s',
                    repl='_',
                    regex=True)
cat.head(18)
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_2192\3893153964.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat.Country=cat.Country.str.replace(pat=r'\s',
#                             Country HDI_2021 Life_expec_2021  \
# 0                               NaN      NaN             NaN
# 1                               NaN      NaN            SDG3
# 2                               NaN      NaN             NaN
# 6       VERY_HIGH_HUMAN_DEVELOPMENT      NaN             NaN
# 73           HIGH_HUMAN_DEVELOPMENT      NaN             NaN
# 123        MEDIUM_HUMAN_DEVELOPMENT      NaN             NaN
# 168           LOW_HUMAN_DEVELOPMENT      NaN             NaN
# 201  OTHER_COUNTRIES_OR_TERRITORIES      NaN             NaN
# ...

# %%
#Define the categories and their limits
data.loc[7:72,'Human_Dev']=cat.Country[6]
data.loc[74:122,'Human_Dev']=cat.Country[73]
data.loc[124:167,'Human_Dev']=cat.Country[123]
data.loc[169:200,'Human_Dev']=cat.Country[168]
data.loc[202:206,'Human_Dev']=cat.Country[201]
data.loc[208:214,'Human_Dev']=cat.Country[207]
data.loc[216:229,'Human_Dev']=cat.Country[215]

mapper1={cat.Country[6]:1,cat.Country[73]:2,cat.Country[123]:3,cat.Country[168]:4,cat.Country[201]:5.1,cat.Country[207]:5.2,cat.Country[215]:5.3}
data.Human_Dev.replace(mapper1,inplace=True)
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_2192\1360047057.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'VERY_HIGH_HUMAN_DEVELOPMENT' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[7:72,'Human_Dev']=cat.Country[6]
# C:\Users\sebas\AppData\Local\Temp\ipykernel_2192\1360047057.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.Human_Dev.replace(mapper1,inplace=True)
# ...

# %%
#Rows
#Check the first 8 rows
data.head(8)
# Out:
#                        Country                       HDI_2021  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN  Human Development Index (HDI)
# 4                      Country                          Value
# 5                          NaN                           2021
# 6  VERY HIGH HUMAN DEVELOPMENT                            NaN
# 7                  Switzerland                            962
#
#             Life_expec_2021      Expec_years_school_2021  \
# 0                       NaN                          NaN
# 1                      SDG3                       SDG4.3
# 2                       NaN                          NaN
# 3  Life expectancy at birth  Expected years of schooling
# 4                   (years)                      (years)
# 5                      2021                         2021
# ...

# %%
#Drop the first 7 rows
byeRows=range(0,7)
data.drop(index=byeRows,inplace=True)

# %%
#Drop every row with a 'Nan' value in the Life_expec_2021 column
data[pd.isnull(data.Life_expec_2021)].index
data.drop(data[pd.isnull(data.Life_expec_2021)].index,inplace=True)

# %%
#Rename the rows
data.index=range(0,210)
data
# Out:
#                                                Country HDI_2021  \
# 0                                          Switzerland      962
# 1                                               Norway      961
# 2                                              Iceland      959
# 3                               Hong Kong, China (SAR)      952
# 4                                            Australia      951
# ..                                                 ...      ...
# 205                                 Sub-Saharan Africa      547
# 206                          Least developed countries      540
# 207                     Small island developing states      730
# 208  Organisation for Economic Co-operation and Dev...      899
# 209                                              World      732
#
#     Life_expec_2021 Expec_years_school_2021 Mean_years_school_2021 GNI_2021  \
# 0              84.0                    16.5                   13.9   66,933
# ...

# %%
#Data
#Remove possibles spaces in the data
def noSpaces(x,errors='coerce'):
  x=x.str.strip()
  return x

data.iloc[:,range(0,8)]=data.iloc[:,range(0,8)].apply(noSpaces)

# %%
#Symbols
#Check symbols other than a dot ('.')
a=set(data.HDI_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
b=set(data.Life_expec_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
c=set(data.Expec_years_school_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
d=set(data.Mean_years_school_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
e=set(data.GNI_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
f=set(data.GNI_minus_HDI_rank_2021.str.extractall('(\W)').loc[:,0].to_list())-set('.')
g=set(data.HDI_rank_2020.str.extractall('(\W)').loc[:,0].to_list())-set('.')
a,b,c,d,e,f,g
# Out:
# (set(), set(), set(), set(), {','}, {'-', '—'}, {'—'})

# %%
#Replace or extract symbols
data.GNI_2021=data.GNI_2021.str.replace(',','') 
data.GNI_minus_HDI_rank_2021=data.GNI_minus_HDI_rank_2021.str.extract(pat=r'(^-\d+$|\d+)')
data.HDI_rank_2020=data.HDI_rank_2020.str.extract(pat=r'(^\w+)')

# %%
#Check for other weird symbols in the HDI_2021 column
data[data.HDI_2021.str.contains(pat=r'\W')]
# Out:
#                                  Country HDI_2021 Life_expec_2021  \
# 191  Korea (Democratic People's Rep. of)       ..            73.3
# 192                               Monaco       ..            85.9
# 193                                Nauru       ..            63.6
# 194                              Somalia       ..            55.3
#
#     Expec_years_school_2021 Mean_years_school_2021 GNI_2021  \
# 191                    10.8                     ..       ..
# 192                      ..                     ..       ..
# 193                    11.7                     ..     1773
# 194                      ..                     ..     1018
#
#     GNI_minus_HDI_rank_2021 HDI_rank_2020  Human_Dev
# 191                     NaN           NaN        5.1
# 192                     NaN           NaN        5.1
# 193                     NaN           NaN        5.1
# 194                     NaN           NaN        5.1

# %%
#Keep the numerical data
data.HDI_2021=data.HDI_2021.str.extract(pat='(\d+)')
data.Expec_years_school_2021=data.Expec_years_school_2021.str.extract(pat='(\d+.\d+)')
data.Mean_years_school_2021=data.Mean_years_school_2021.str.extract(pat='(\d+.\d+)')
data.GNI_2021=data.GNI_2021.str.extract(pat='(\d+)')

# %%
#FORMATTING
#Check for the data frame information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  210 non-null    object
#  1   HDI_2021                 206 non-null    object
#  2   Life_expec_2021          210 non-null    object
#  3   Expec_years_school_2021  208 non-null    object
#  4   Mean_years_school_2021   206 non-null    object
#  5   GNI_2021                 208 non-null    object
#  6   GNI_minus_HDI_rank_2021  191 non-null    object
#  7   HDI_rank_2020            191 non-null    object
#  8   Human_Dev                210 non-null    float64
# dtypes: float64(1), object(8)
# memory usage: 14.9+ KB

# %%
#Look for duplicates in Country
data[data.duplicated(subset='Country')]
# Out:
# Empty DataFrame
# Columns: [Country, HDI_2021, Life_expec_2021, Expec_years_school_2021, Mean_years_school_2021, GNI_2021, GNI_minus_HDI_rank_2021, HDI_rank_2020, Human_Dev]
# Index: []

# %%
#Search for weird symbols or spaces
data[data.Country.str.contains(r'[^\w\s]')]
# Out:
#                                                Country HDI_2021  \
# 3                               Hong Kong, China (SAR)      952
# 19                                 Korea (Republic of)      925
# 75                          Iran (Islamic Republic of)      774
# 80                               Moldova (Republic of)      767
# 105                                Palestine, State of      715
# 117                   Bolivia (Plurinational State of)      692
# 119                 Venezuela (Bolivarian Republic of)      691
# 133                   Micronesia (Federated States of)      628
# 139                   Lao People's Democratic Republic      607
# 140                                        Timor-Leste      607
# 143                              Eswatini (Kingdom of)      597
# 158                                      Côte d'Ivoire      550
# 159                      Tanzania (United Republic of)      549
# 176                                      Guinea-Bissau      483
# ...

# %%
#Search for accentuation and similar ASCII symbols
data[data.Country.str.contains(r"\w*[\u00C0-\u01DA']\w*")]
# Out:
#                                  Country HDI_2021 Life_expec_2021  \
# 47                               Türkiye      838            76.0
# 139     Lao People's Democratic Republic      607            68.1
# 158                        Côte d'Ivoire      550            58.6
# 191  Korea (Democratic People's Rep. of)      NaN            73.3
#
#     Expec_years_school_2021 Mean_years_school_2021 GNI_2021  \
# 47                     18.3                    8.6    31033
# 139                    10.1                    5.4     7700
# 158                    10.7                    5.2     5217
# 191                    10.8                    NaN      NaN
#
#     GNI_minus_HDI_rank_2021 HDI_rank_2020  Human_Dev
# 47                       -3            48        1.0
# 139                     -18           142        3.0
# 158                     -22           159        3.0
# 191                     NaN           NaN        5.1

# %%
pip install unidecode
# Out:
# ...
#    ---------------------------------------- 0.0/235.5 kB ? eta -:--:--
#    - -------------------------------------- 10.2/235.5 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/235.5 kB 320.0 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/235.5 kB 326.8 kB/s eta 0:00:01
#    ----------------------- -------------- 143.4/235.5 kB 944.1 kB/s eta 0:00:01
#    ---------------------------------------- 235.5/235.5 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Change the data into a new and same format
from unidecode import unidecode

data['Country']=data.Country.apply(unidecode)
data['Country']=data.Country.str.upper()

# %%
#Search for data with any symbol different than a number or a dot
def symbols(x,errors='ignore'):
  x=x.str.contains(r'\D\.')
  return x

symbols(data.HDI_2021).value_counts()
# Out:
# HDI_2021
# False    206
# Name: count, dtype: int64

# %%
symbols(data.Life_expec_2021).value_counts()
# Out:
# Life_expec_2021
# False    210
# Name: count, dtype: int64

# %%
symbols(data.Expec_years_school_2021).value_counts()
# Out:
# Expec_years_school_2021
# False    208
# Name: count, dtype: int64

# %%
symbols(data.Mean_years_school_2021).value_counts()
# Out:
# Mean_years_school_2021
# False    206
# Name: count, dtype: int64

# %%
symbols(data.GNI_2021).value_counts()
# Out:
# GNI_2021
# False    208
# Name: count, dtype: int64

# %%
symbols(data.GNI_minus_HDI_rank_2021).value_counts()
# Out:
# GNI_minus_HDI_rank_2021
# False    191
# Name: count, dtype: int64

# %%
symbols(data.HDI_rank_2020).value_counts()
# Out:
# HDI_rank_2020
# False    191
# Name: count, dtype: int64

# %%
#Change the data type to numeric
data.HDI_2021 = pd.to_numeric(data.HDI_2021,errors='coerce')
data.Life_expec_2021 = pd.to_numeric(data.Life_expec_2021,errors='coerce')
data.Expec_years_school_2021 = pd.to_numeric(data.Expec_years_school_2021,errors='coerce')
data.Mean_years_school_2021 = pd.to_numeric(data.Mean_years_school_2021,errors='coerce')
data.GNI_2021 = pd.to_numeric(data.GNI_2021,errors='coerce')
data.GNI_minus_HDI_rank_2021 = pd.to_numeric(data.GNI_minus_HDI_rank_2021,errors='coerce')
data.HDI_rank_2020 = pd.to_numeric(data.HDI_rank_2020,errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  210 non-null    object
#  1   HDI_2021                 206 non-null    float64
#  2   Life_expec_2021          210 non-null    float64
#  3   Expec_years_school_2021  208 non-null    float64
#  4   Mean_years_school_2021   206 non-null    float64
#  5   GNI_2021                 208 non-null    float64
#  6   GNI_minus_HDI_rank_2021  191 non-null    float64
#  7   HDI_rank_2020            191 non-null    float64
#  8   Human_Dev                210 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 14.9+ KB

# %%
data
# Out:
#                                                Country  HDI_2021  \
# 0                                          SWITZERLAND     962.0
# 1                                               NORWAY     961.0
# 2                                              ICELAND     959.0
# 3                               HONG KONG, CHINA (SAR)     952.0
# 4                                            AUSTRALIA     951.0
# ..                                                 ...       ...
# 205                                 SUB-SAHARAN AFRICA     547.0
# 206                          LEAST DEVELOPED COUNTRIES     540.0
# 207                     SMALL ISLAND DEVELOPING STATES     730.0
# 208  ORGANISATION FOR ECONOMIC CO-OPERATION AND DEV...     899.0
# 209                                              WORLD     732.0
#
#      Life_expec_2021  Expec_years_school_2021  Mean_years_school_2021  \
# 0               84.0                     16.5                    13.9
# ...
